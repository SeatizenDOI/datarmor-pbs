# %%
from pathlib import Path 

FOLDER = Path("/home1/datahome/villien/PBS/odm/drone")

for file in FOLDER.iterdir():

    if ".o2385139" not in file.name: continue
        
    with open(file, "r") as fp:
        isFound = False
        for row in fp:
            if "ODM app finished - " in row:
                isFound = True
                break
        if not isFound:
            print("Something wrent wrong with", file)
# Out:
# Something wrent wrong with /home1/datahome/villien/PBS/odm/drone/odm_drone.o2385139.13
# Something wrent wrong with /home1/datahome/villien/PBS/odm/drone/odm_drone.o2385139.4
