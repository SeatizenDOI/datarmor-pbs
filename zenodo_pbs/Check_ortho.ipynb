# %%
from pathlib import Path

PATH_FOLDER = Path("/scale/project/rummo/plancha-session")

# %%
for session in sorted(list(PATH_FOLDER.iterdir())):

    photog_folder = Path(session, "PROCESSED_DATA", "PHOTOGRAMMETRY")

    if not photog_folder.exists() or len(list(photog_folder.iterdir())) == 0: continue
        
    print(session)
# Out:
# /scale/project/rummo/plancha-session/20230906_REU-BOUCAN_ASV-1_02
# /scale/project/rummo/plancha-session/20230907_REU-BOUCAN_ASV-1_01
# /scale/project/rummo/plancha-session/20231018_REU-ST-LEU_ASV-2_01
# /scale/project/rummo/plancha-session/20231109_REU-BOUCAN_ASV-2_03
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-1_01
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-1_02
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-1_03
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-1_04
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-2_01
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-2_02
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-2_03
# /scale/project/rummo/plancha-session/20231110_REU-ST-LEU_ASV-2_04
# /scale/project/rummo/plancha-session/20231121_REU-BOUCAN_ASV-1_01
# /scale/project/rummo/plancha-session/20231121_REU-BOUCAN_ASV-1_02
# ...
